# %%
import pandas as pd
import re

#read train data from file
csv_file_path = 'data.csv'

# Lesen der CSV-Datei
df = pd.read_csv(csv_file_path)

df.replace(to_replace='\n', value='', regex=True, inplace=True)
# df.replace(to_replace='  ', value=',', regex=True, inplace=True)


# print(df.head())


regex_pattern = r'(\d+(\.\d+)?)\s+'

# Ersetzen der gefundenen Leerzeichen durch ein Komma und ein Leerzeichen
ret = [[re.sub(regex_pattern, r'\1, ', line) for line in df.Distance]]

print([[line for line in df.Distance]])

# Ausgabe des modifizierten Strings
# print(ret[:5])

# [[i.split(" ") for i in df.Distance]]
# arrays = {col: list(df[col]) for col in df}

# print(arrays[0])



# print(df.head(9))

# print(type(df['Distance'][0]))


# df['Distance'] = df['Distance'].astype(float)

# print(type(df.Distance))

# print(df.head(9))
# Out:
# [['[ 5.968  6.09   6.3    6.434  6.602  6.78   6.996  7.215  7.442  7.692  7.958  8.223  7.992  7.957  7.946  7.932  8.199  8.064 10.278  1.23  1.228  1.228  1.229  1.25   1.268  1.251  1.27   1.273  1.272  1.26  1.277  1.304  1.298  1.304  1.302  7.944  7.98   7.971  7.971  7.978  7.947  7.98   7.971  7.992  7.983  7.983  7.992  7.983  8.024  8.006  8.017  8.016  8.007  8.017  7.984  7.994  8.016  7.998  8.022  8.036  7.971  8.004  8.012  7.995  7.998  8.014  8.05   8.025  7.987  7.994  8.051  8.007  8.004  7.984  7.996  8.024  8.007  8.013  8.014  8.061  9.939  9.904  9.935  7.908  7.92   8.031  8.057  8.112  8.156  7.952  7.94   7.967  7.903  7.884  7.937  7.963  7.958  7.974  8.002  8.017  7.981  7.995  7.996  8.642  9.816  8.967  8.901  8.803  8.753  8.153  8.116  7.975  7.969  7.989  7.986  8.03   7.512  7.955  7.992  7.971  9.72   8.256  8.175  9.611  9.528  9.396  9.363  9.27   9.304  9.276  9.18   9.136  9.098  9.024  9.     8.964  7.896  7.824  7.812  7.788  7.74   7.761  7
# ...
